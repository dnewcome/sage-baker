# %%
import sys; sys.path.insert(0, "src")                                                                               
# %load_ext autoreload                                                                      
# %autoreload 2                

import bundle, train                                                                                                
import pandas as pd
